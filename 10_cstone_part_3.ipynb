# %%
# %matplotlib notebook

# %%
# Purpose of this notebook: test LSTM model on SPY data 
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
# Out:
# Using TensorFlow backend.

# %%
# convert p_t into a X,Y matrices for classification task
def create_dataset(p_t, dt_back=1):
    dataX, dataY = [], []
    
    for i in range(len(p_t)-dt_back-1):
        a = p_t[i:(i+dt_back), 0]
        dataX.append(a)
        dataY.append(p_t[i + dt_back, 0])
    return np.array(dataX), np.array(dataY)
#end def create_dataset

# %%
# fix random seed for reproducibility
np.random.seed(7)

# load the p_t
df = read_csv('sp500.csv', usecols=[0], engine='python', skipfooter=3)
p_t = df.values       
p_t = p_t.astype('float32')

# %%
#p_t.shape   #df.values

# %%
# normalize the p_t
scaler = MinMaxScaler(feature_range=(0, 1))
p_t = scaler.fit_transform(p_t)

# split into train and test sets
N_train = int(len(p_t) * 0.67)
N_test = len(p_t) - N_train
train, test = p_t[0:N_train,:], p_t[N_train:len(p_t),:]

# %%
# reshape into X=t and Y=t+1
dt_back = 30     # look back time period
trainX, trainY = create_dataset(train, dt_back)
testX, testY = create_dataset(test, dt_back)

# %%
print(trainX.shape,trainY.shape)
# Out:
# (2746, 30) (2746,)

# %%
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX,(trainX.shape[0],trainX.shape[1],1))   # (trainX.shape[0], 1, trainX.shape[1])
testX = np.reshape(testX,(testX.shape[0],testX.shape[1],1))   # (testX.shape[0], 1, testX.shape[1])

# %%
trainX.shape
# Out:
# (2746, 30, 1)

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(100, input_shape=(dt_back,1)))   # input_shape=(1, dt_back)
model.add(Dense(1))

# compile and fit the model
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
for Nb in range(7,64):
    print('------ batch_size=',Nb)
    model = Sequential()
    model.add(LSTM(100, input_shape=(dt_back,1)))   # input_shape=(1, dt_back)
    model.add(Dense(1))
    
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.fit(trainX, trainY, epochs=5, batch_size=Nb, verbose=2)

    # make predictions
    trainPredict = model.predict(trainX)
    testPredict = model.predict(testX)

    # invert predictions
    p_train_pred_t = scaler.inverse_transform(trainPredict)
    trainY1 = scaler.inverse_transform([trainY])
    p_test_pred_t = scaler.inverse_transform(testPredict)
    testY1 = scaler.inverse_transform([testY])

    # calculate root mean squared error
    trainScore = math.sqrt(mean_squared_error(trainY1[0], p_train_pred_t[:,0]))
    print('Train Score: %.2f RMSE' % (trainScore))
    testScore = math.sqrt(mean_squared_error(testY1[0], p_test_pred_t[:,0]))
    print('Test Score: %.2f RMSE' % (testScore))
    
    print('***')
    
# end for Nb in range(7,64):
# Out:
# ------ batch_size= 7
# Epoch 1/5
# 5s - loss: 0.0017
# Epoch 2/5
# 4s - loss: 3.1305e-04
# Epoch 3/5
# 4s - loss: 2.7686e-04
# Epoch 4/5
# 4s - loss: 2.5823e-04
# Epoch 5/5
# 4s - loss: 2.2274e-04
# Train Score: 21.79 RMSE
# Test Score: 23.87 RMSE
# ***
# ------ batch_size= 8
# Epoch 1/5
# 4s - loss: 0.0024
# Epoch 2/5
# 4s - loss: 3.3272e-04
# Epoch 3/5
# 4s - loss: 2.8020e-04
# Epoch 4/5
# 4s - loss: 2.5833e-04
# Epoch 5/5
# 4s - loss: 2.5090e-04
# Train Score: 21.99 RMSE
# Test Score: 24.19 RMSE
# ***
# ------ batch_size= 9
# Epoch 1/5
# 4s - loss: 0.0035
# Epoch 2/5
# 3s - loss: 3.3005e-04
# Epoch 3/5
# 3s - loss: 2.8751e-04
# Epoch 4/5
# 4s - loss: 2.7547e-04
# Epoch 5/5
# 3s - loss: 2.7471e-04
# Train Score: 21.48 RMSE
# Test Score: 26.94 RMSE
# ***
# ------ batch_size= 10
# Epoch 1/5
# 4s - loss: 0.0035
# Epoch 2/5
# 3s - loss: 3.6689e-04
# Epoch 3/5
# 3s - loss: 3.1051e-04
# Epoch 4/5
# 3s - loss: 2.8643e-04
# Epoch 5/5
# 3s - loss: 2.5619e-04
# Train Score: 24.29 RMSE
# Test Score: 26.94 RMSE
# ***
# ------ batch_size= 11
# Epoch 1/5
# 4s - loss: 0.0023
# Epoch 2/5
# 3s - loss: 3.0348e-04
# Epoch 3/5
# 3s - loss: 2.8364e-04
# Epoch 4/5
# 3s - loss: 2.5316e-04
# Epoch 5/5
# 3s - loss: 2.4368e-04
# Train Score: 21.09 RMSE
# Test Score: 23.97 RMSE
# ***
# ------ batch_size= 12
# Epoch 1/5
# 4s - loss: 0.0036
# Epoch 2/5
# 3s - loss: 3.2981e-04
# Epoch 3/5
# 3s - loss: 3.2868e-04
# Epoch 4/5
# 3s - loss: 2.9402e-04
# Epoch 5/5
# 3s - loss: 2.6239e-04
# Train Score: 22.57 RMSE
# Test Score: 24.31 RMSE
# ***
# ------ batch_size= 13
# Epoch 1/5
# 3s - loss: 0.0027
# Epoch 2/5
# 2s - loss: 3.1971e-04
# Epoch 3/5
# 2s - loss: 2.9422e-04
# Epoch 4/5
# 3s - loss: 2.6007e-04
# Epoch 5/5
# 2s - loss: 2.5779e-04
# Train Score: 23.72 RMSE
# Test Score: 26.29 RMSE
# ***
# ------ batch_size= 14
# Epoch 1/5
# 4s - loss: 0.0031
# Epoch 2/5
# 2s - loss: 3.0655e-04
# Epoch 3/5
# 2s - loss: 3.0333e-04
# Epoch 4/5
# 3s - loss: 2.7147e-04
# Epoch 5/5
# 2s - loss: 2.4661e-04
# Train Score: 22.28 RMSE
# Test Score: 32.00 RMSE
# ***
# ------ batch_size= 15
# Epoch 1/5
# 3s - loss: 0.0043
# Epoch 2/5
# 2s - loss: 3.4157e-04
# Epoch 3/5
# 2s - loss: 3.4334e-04
# Epoch 4/5
# 2s - loss: 3.0770e-04
# Epoch 5/5
# 2s - loss: 2.8409e-04
# Train Score: 23.31 RMSE
# Test Score: 27.71 RMSE
# ***
# ------ batch_size= 16
# Epoch 1/5
# 3s - loss: 0.0039
# Epoch 2/5
# 2s - loss: 3.1431e-04
# Epoch 3/5
# 2s - loss: 3.2739e-04
# Epoch 4/5
# 2s - loss: 2.8024e-04
# Epoch 5/5
# 2s - loss: 2.6825e-04
# Train Score: 23.16 RMSE
# Test Score: 32.04 RMSE
# ***
# ------ batch_size= 17
# Epoch 1/5
# 3s - loss: 0.0045
# Epoch 2/5
# 2s - loss: 3.4171e-04
# Epoch 3/5
# 2s - loss: 3.3194e-04
# Epoch 4/5
# 2s - loss: 2.9124e-04
# Epoch 5/5
# 2s - loss: 2.8219e-04
# Train Score: 23.03 RMSE
# Test Score: 26.15 RMSE
# ***
# ------ batch_size= 18
# Epoch 1/5
# 3s - loss: 0.0039
# Epoch 2/5
# 2s - loss: 3.0517e-04
# Epoch 3/5
# 2s - loss: 2.9316e-04
# Epoch 4/5
# 2s - loss: 2.6532e-04
# Epoch 5/5
# 2s - loss: 2.4252e-04
# Train Score: 22.08 RMSE
# Test Score: 24.62 RMSE
# ***
# ------ batch_size= 19
# Epoch 1/5
# 3s - loss: 0.0052
# Epoch 2/5
# 2s - loss: 3.6503e-04
# Epoch 3/5
# 2s - loss: 3.4611e-04
# Epoch 4/5
# 2s - loss: 3.2015e-04
# Epoch 5/5
# 2s - loss: 2.9599e-04
# Train Score: 24.50 RMSE
# Test Score: 28.25 RMSE
# ***
# ------ batch_size= 20
# Epoch 1/5
# 3s - loss: 0.0058
# Epoch 2/5
# 2s - loss: 3.3602e-04
# Epoch 3/5
# 2s - loss: 3.0930e-04
# Epoch 4/5
# 2s - loss: 3.0664e-04
# Epoch 5/5
# 2s - loss: 2.7523e-04
# Train Score: 25.56 RMSE
# Test Score: 29.34 RMSE
# ***
# ------ batch_size= 21
# Epoch 1/5
# 3s - loss: 0.0050
# Epoch 2/5
# 2s - loss: 3.0746e-04
# Epoch 3/5
# 2s - loss: 3.0684e-04
# Epoch 4/5
# 2s - loss: 2.9322e-04
# Epoch 5/5
# 2s - loss: 2.7346e-04
# Train Score: 23.07 RMSE
# Test Score: 26.11 RMSE
# ***
# ------ batch_size= 22
# Epoch 1/5
# 3s - loss: 0.0056
# Epoch 2/5
# 2s - loss: 3.1525e-04
# Epoch 3/5
# 2s - loss: 3.0378e-04
# Epoch 4/5
# 2s - loss: 2.9025e-04
# Epoch 5/5
# 2s - loss: 2.7539e-04
# Train Score: 23.49 RMSE
# Test Score: 27.99 RMSE
# ***
# ------ batch_size= 23
# Epoch 1/5
# 3s - loss: 0.0054
# Epoch 2/5
# 2s - loss: 3.1317e-04
# Epoch 3/5
# 2s - loss: 3.0027e-04
# Epoch 4/5
# 2s - loss: 2.9613e-04
# Epoch 5/5
# 2s - loss: 3.0782e-04
# Train Score: 26.81 RMSE
# Test Score: 41.76 RMSE
# ***
# ------ batch_size= 24
# Epoch 1/5
# 3s - loss: 0.0081
# Epoch 2/5
# 2s - loss: 3.8596e-04
# Epoch 3/5
# 2s - loss: 3.6918e-04
# Epoch 4/5
# 2s - loss: 3.4169e-04
# Epoch 5/5
# 2s - loss: 3.2931e-04
# Train Score: 25.64 RMSE
# Test Score: 30.51 RMSE
# ***
# ------ batch_size= 25
# Epoch 1/5
# 3s - loss: 0.0062
# Epoch 2/5
# 2s - loss: 3.2665e-04
# Epoch 3/5
# 2s - loss: 3.0965e-04
# Epoch 4/5
# 2s - loss: 2.9253e-04
# Epoch 5/5
# 2s - loss: 2.8365e-04
# Train Score: 25.57 RMSE
# Test Score: 28.76 RMSE
# ***
# ------ batch_size= 26
# Epoch 1/5
# 3s - loss: 0.0059
# Epoch 2/5
# 1s - loss: 3.5453e-04
# Epoch 3/5
# 1s - loss: 3.3698e-04
# Epoch 4/5
# 2s - loss: 3.1393e-04
# Epoch 5/5
# 1s - loss: 2.9645e-04
# Train Score: 24.54 RMSE
# Test Score: 28.94 RMSE
# ***
# ------ batch_size= 27
# Epoch 1/5
# 3s - loss: 0.0063
# Epoch 2/5
# 1s - loss: 3.4021e-04
# Epoch 3/5
# 2s - loss: 3.3218e-04
# Epoch 4/5
# 1s - loss: 3.2490e-04
# Epoch 5/5
# 1s - loss: 3.0050e-04
# Train Score: 24.29 RMSE
# Test Score: 29.11 RMSE
# ***
# ------ batch_size= 28
# Epoch 1/5
# 3s - loss: 0.0047
# Epoch 2/5
# 1s - loss: 3.1655e-04
# Epoch 3/5
# 1s - loss: 3.0788e-04
# Epoch 4/5
# 1s - loss: 3.1006e-04
# Epoch 5/5
# 1s - loss: 2.7986e-04
# Train Score: 25.66 RMSE
# Test Score: 29.50 RMSE
# ***
# ------ batch_size= 29
# Epoch 1/5
# 3s - loss: 0.0086
# Epoch 2/5
# 1s - loss: 3.6875e-04
# Epoch 3/5
# 1s - loss: 3.5889e-04
# Epoch 4/5
# 1s - loss: 3.4777e-04
# Epoch 5/5
# 1s - loss: 3.2803e-04
# Train Score: 25.47 RMSE
# Test Score: 31.16 RMSE
# ***
# ------ batch_size= 30
# Epoch 1/5
# 3s - loss: 0.0074
# Epoch 2/5
# 1s - loss: 3.0858e-04
# Epoch 3/5
# 1s - loss: 3.0183e-04
# Epoch 4/5
# 1s - loss: 2.8337e-04
# Epoch 5/5
# 1s - loss: 2.8074e-04
# Train Score: 25.55 RMSE
# Test Score: 29.00 RMSE
# ***
# ------ batch_size= 31
# Epoch 1/5
# 3s - loss: 0.0075
# Epoch 2/5
# 2s - loss: 3.2050e-04
# Epoch 3/5
# 1s - loss: 3.0143e-04
# Epoch 4/5
# 1s - loss: 2.9746e-04
# Epoch 5/5
# 1s - loss: 2.8563e-04
# Train Score: 24.89 RMSE
# Test Score: 42.33 RMSE
# ***
# ------ batch_size= 32
# Epoch 1/5
# 3s - loss: 0.0103
# Epoch 2/5
# 1s - loss: 4.0008e-04
# Epoch 3/5
# 2s - loss: 3.7160e-04
# Epoch 4/5
# 1s - loss: 3.5070e-04
# Epoch 5/5
# 1s - loss: 3.4047e-04
# Train Score: 25.88 RMSE
# Test Score: 33.55 RMSE
# ***
# ------ batch_size= 33
# Epoch 1/5
# 3s - loss: 0.0069
# Epoch 2/5
# 1s - loss: 3.2996e-04
# Epoch 3/5
# 1s - loss: 3.1685e-04
# Epoch 4/5
# 2s - loss: 3.0221e-04
# Epoch 5/5
# 1s - loss: 2.9057e-04
# Train Score: 24.19 RMSE
# Test Score: 30.33 RMSE
# ***
# ------ batch_size= 34
# Epoch 1/5
# 3s - loss: 0.0074
# Epoch 2/5
# 1s - loss: 3.3118e-04
# Epoch 3/5
# 1s - loss: 3.1913e-04
# Epoch 4/5
# 1s - loss: 3.0547e-04
# Epoch 5/5
# 1s - loss: 3.0053e-04
# Train Score: 24.66 RMSE
# Test Score: 29.92 RMSE
# ***
# ------ batch_size= 35
# Epoch 1/5
# 3s - loss: 0.0086
# Epoch 2/5
# 1s - loss: 3.7748e-04
# Epoch 3/5
# 1s - loss: 3.4204e-04
# Epoch 4/5
# 1s - loss: 3.4083e-04
# Epoch 5/5
# 1s - loss: 3.2564e-04
# Train Score: 25.54 RMSE
# Test Score: 32.27 RMSE
# ***
# ------ batch_size= 36
# Epoch 1/5
# 3s - loss: 0.0075
# Epoch 2/5
# 1s - loss: 3.1554e-04
# Epoch 3/5
# 1s - loss: 2.9775e-04
# Epoch 4/5
# 1s - loss: 2.9455e-04
# Epoch 5/5
# 1s - loss: 2.8706e-04
# Train Score: 24.49 RMSE
# Test Score: 28.79 RMSE
# ***
# ------ batch_size= 37
# Epoch 1/5
# 3s - loss: 0.0090
# Epoch 2/5
# 1s - loss: 3.9933e-04
# Epoch 3/5
# 1s - loss: 3.5272e-04
# Epoch 4/5
# 1s - loss: 3.4916e-04
# Epoch 5/5
# 1s - loss: 3.3323e-04
# Train Score: 28.22 RMSE
# Test Score: 41.14 RMSE
# ***
# ------ batch_size= 38
# Epoch 1/5
# 3s - loss: 0.0145
# Epoch 2/5
# 1s - loss: 4.8307e-04
# Epoch 3/5
# 1s - loss: 4.0325e-04
# Epoch 4/5
# 1s - loss: 3.8149e-04
# Epoch 5/5
# 1s - loss: 3.6853e-04
# Train Score: 27.22 RMSE
# Test Score: 38.73 RMSE
# ***
# ------ batch_size= 39
# Epoch 1/5
# 3s - loss: 0.0097
# Epoch 2/5
# 1s - loss: 3.9353e-04
# Epoch 3/5
# 1s - loss: 3.5061e-04
# Epoch 4/5
# 1s - loss: 3.3293e-04
# Epoch 5/5
# 1s - loss: 3.2308e-04
# Train Score: 25.51 RMSE
# Test Score: 33.82 RMSE
# ***
# ------ batch_size= 40
# Epoch 1/5
# 3s - loss: 0.0079
# Epoch 2/5
# 1s - loss: 3.5645e-04
# Epoch 3/5
# 1s - loss: 3.0839e-04
# Epoch 4/5
# 1s - loss: 2.9774e-04
# Epoch 5/5
# 1s - loss: 2.9718e-04
# Train Score: 27.21 RMSE
# Test Score: 29.84 RMSE
# ***
# ------ batch_size= 41
# Epoch 1/5
# 3s - loss: 0.0089
# Epoch 2/5
# 1s - loss: 3.5584e-04
# Epoch 3/5
# 1s - loss: 3.0081e-04
# Epoch 4/5
# 1s - loss: 2.9151e-04
# Epoch 5/5
# 1s - loss: 2.8290e-04
# Train Score: 24.37 RMSE
# Test Score: 30.44 RMSE
# ***
# ------ batch_size= 42
# Epoch 1/5
# 3s - loss: 0.0103
# Epoch 2/5
# 1s - loss: 3.9753e-04
# Epoch 3/5
# 1s - loss: 3.2040e-04
# Epoch 4/5
# 1s - loss: 3.1546e-04
# Epoch 5/5
# 1s - loss: 3.1297e-04
# Train Score: 25.34 RMSE
# Test Score: 38.36 RMSE
# ***
# ------ batch_size= 43
# Epoch 1/5
# 3s - loss: 0.0114
# Epoch 2/5
# 1s - loss: 4.4257e-04
# Epoch 3/5
# 1s - loss: 3.2485e-04
# Epoch 4/5
# 1s - loss: 3.1433e-04
# Epoch 5/5
# 1s - loss: 3.0555e-04
# Train Score: 25.25 RMSE
# Test Score: 38.96 RMSE
# ***
# ------ batch_size= 44
# Epoch 1/5
# 3s - loss: 0.0159
# Epoch 2/5
# 1s - loss: 5.4722e-04
# Epoch 3/5
# 1s - loss: 3.4933e-04
# Epoch 4/5
# 1s - loss: 3.4400e-04
# Epoch 5/5
# 1s - loss: 3.3165e-04
# Train Score: 26.34 RMSE
# Test Score: 48.70 RMSE
# ***
# ------ batch_size= 45
# Epoch 1/5
# 3s - loss: 0.0069
# Epoch 2/5
# 1s - loss: 3.7148e-04
# Epoch 3/5
# 1s - loss: 3.0521e-04
# Epoch 4/5
# 1s - loss: 3.0802e-04
# Epoch 5/5
# 1s - loss: 3.0854e-04
# Train Score: 24.38 RMSE
# Test Score: 28.91 RMSE
# ***
# ------ batch_size= 46
# Epoch 1/5
# 3s - loss: 0.0112
# Epoch 2/5
# 1s - loss: 4.4493e-04
# Epoch 3/5
# 1s - loss: 3.2558e-04
# Epoch 4/5
# 1s - loss: 3.2155e-04
# Epoch 5/5
# 1s - loss: 3.0979e-04
# Train Score: 25.28 RMSE
# Test Score: 36.99 RMSE
# ***
# ------ batch_size= 47
# Epoch 1/5
# 3s - loss: 0.0098
# Epoch 2/5
# 1s - loss: 3.8507e-04
# Epoch 3/5
# 1s - loss: 3.0484e-04
# Epoch 4/5
# 1s - loss: 2.9868e-04
# Epoch 5/5
# 1s - loss: 2.8568e-04
# Train Score: 24.69 RMSE
# Test Score: 45.89 RMSE
# ***
# ------ batch_size= 48
# Epoch 1/5
# 3s - loss: 0.0115
# Epoch 2/5
# 1s - loss: 4.9361e-04
# Epoch 3/5
# 1s - loss: 3.5470e-04
# Epoch 4/5
# 1s - loss: 3.4237e-04
# Epoch 5/5
# 1s - loss: 3.2749e-04
# Train Score: 25.96 RMSE
# Test Score: 35.29 RMSE
# ***
# ------ batch_size= 49
# Epoch 1/5
# 4s - loss: 0.0122
# Epoch 2/5
# 1s - loss: 5.5226e-04
# Epoch 3/5
# 1s - loss: 3.0614e-04
# Epoch 4/5
# 1s - loss: 3.0787e-04
# Epoch 5/5
# 1s - loss: 2.9277e-04
# Train Score: 24.84 RMSE
# Test Score: 49.55 RMSE
# ***
# ------ batch_size= 50
# Epoch 1/5
# 3s - loss: 0.0078
# Epoch 2/5
# 1s - loss: 4.0229e-04
# Epoch 3/5
# 1s - loss: 2.8887e-04
# Epoch 4/5
# 1s - loss: 2.8742e-04
# Epoch 5/5
# 1s - loss: 2.8296e-04
# Train Score: 24.46 RMSE
# Test Score: 34.56 RMSE
# ***
# ------ batch_size= 51
# Epoch 1/5
# 3s - loss: 0.0146
# Epoch 2/5
# 1s - loss: 6.4518e-04
# Epoch 3/5
# 1s - loss: 3.5866e-04
# Epoch 4/5
# 1s - loss: 3.5651e-04
# Epoch 5/5
# 1s - loss: 3.4292e-04
# Train Score: 26.87 RMSE
# Test Score: 47.94 RMSE
# ***
# ------ batch_size= 52
# Epoch 1/5
# 4s - loss: 0.0111
# Epoch 2/5
# 1s - loss: 5.1228e-04
# Epoch 3/5
# 1s - loss: 3.1910e-04
# Epoch 4/5
# 1s - loss: 3.1205e-04
# Epoch 5/5
# 1s - loss: 3.0790e-04
# Train Score: 25.01 RMSE
# Test Score: 43.16 RMSE
# ***
# ------ batch_size= 53
# Epoch 1/5
# 4s - loss: 0.0162
# Epoch 2/5
# 1s - loss: 6.9762e-04
# Epoch 3/5
# 1s - loss: 3.3702e-04
# Epoch 4/5
# 1s - loss: 3.3106e-04
# Epoch 5/5
# 1s - loss: 3.2572e-04
# Train Score: 25.90 RMSE
# Test Score: 42.13 RMSE
# ***
# ------ batch_size= 54
# Epoch 1/5
# 4s - loss: 0.0111
# Epoch 2/5
# 1s - loss: 5.2991e-04
# Epoch 3/5
# 1s - loss: 3.3028e-04
# Epoch 4/5
# 1s - loss: 3.2255e-04
# Epoch 5/5
# 1s - loss: 3.2063e-04
# Train Score: 25.67 RMSE
# Test Score: 43.58 RMSE
# ***
# ------ batch_size= 55
# Epoch 1/5
# 4s - loss: 0.0155
# Epoch 2/5
# 1s - loss: 6.8057e-04
# Epoch 3/5
# 1s - loss: 3.4141e-04
# Epoch 4/5
# 1s - loss: 3.3380e-04
# Epoch 5/5
# 1s - loss: 3.2652e-04
# Train Score: 25.92 RMSE
# Test Score: 39.95 RMSE
# ***
# ------ batch_size= 56
# Epoch 1/5
# 4s - loss: 0.0107
# Epoch 2/5
# 1s - loss: 5.8245e-04
# Epoch 3/5
# 1s - loss: 3.7104e-04
# Epoch 4/5
# 1s - loss: 3.4852e-04
# Epoch 5/5
# 1s - loss: 3.4017e-04
# Train Score: 26.54 RMSE
# Test Score: 37.95 RMSE
# ***
# ------ batch_size= 57
# Epoch 1/5
# 4s - loss: 0.0232
# Epoch 2/5
# 1s - loss: 9.0163e-04
# Epoch 3/5
# 1s - loss: 3.8816e-04
# Epoch 4/5
# 1s - loss: 3.8149e-04
# Epoch 5/5
# 1s - loss: 3.6290e-04
# Train Score: 27.34 RMSE
# Test Score: 43.82 RMSE
# ***
# ------ batch_size= 58
# Epoch 1/5
# 4s - loss: 0.0140
# Epoch 2/5
# 1s - loss: 6.9326e-04
# Epoch 3/5
# 1s - loss: 3.5153e-04
# Epoch 4/5
# 1s - loss: 3.4473e-04
# Epoch 5/5
# 1s - loss: 3.3566e-04
# Train Score: 26.24 RMSE
# Test Score: 43.65 RMSE
# ***
# ------ batch_size= 59
# Epoch 1/5
# 4s - loss: 0.0178
# Epoch 2/5
# 1s - loss: 8.2973e-04
# Epoch 3/5
# 1s - loss: 4.0397e-04
# Epoch 4/5
# 1s - loss: 3.7650e-04
# Epoch 5/5
# 1s - loss: 3.7515e-04
# Train Score: 27.67 RMSE
# Test Score: 42.37 RMSE
# ***
# ------ batch_size= 60
# Epoch 1/5
# 4s - loss: 0.0065
# Epoch 2/5
# 1s - loss: 4.3281e-04
# Epoch 3/5
# 1s - loss: 2.8144e-04
# Epoch 4/5
# 1s - loss: 2.7989e-04
# Epoch 5/5
# 1s - loss: 2.7553e-04
# Train Score: 23.86 RMSE
# Test Score: 27.59 RMSE
# ***
# ------ batch_size= 61
# Epoch 1/5
# 4s - loss: 0.0112
# Epoch 2/5
# 1s - loss: 6.4159e-04
# Epoch 3/5
# 1s - loss: 3.2384e-04
# Epoch 4/5
# 1s - loss: 3.1205e-04
# Epoch 5/5
# 1s - loss: 3.0683e-04
# Train Score: 25.36 RMSE
# Test Score: 30.34 RMSE
# ***
# ------ batch_size= 62
# Epoch 1/5
# 4s - loss: 0.0107
# Epoch 2/5
# 1s - loss: 5.8137e-04
# Epoch 3/5
# 1s - loss: 2.9155e-04
# Epoch 4/5
# 1s - loss: 2.8466e-04
# Epoch 5/5
# 1s - loss: 2.8029e-04
# Train Score: 24.21 RMSE
# Test Score: 34.37 RMSE
# ***
# ------ batch_size= 63
# Epoch 1/5
# 4s - loss: 0.0125
# Epoch 2/5
# 1s - loss: 7.8824e-04
# Epoch 3/5
# 1s - loss: 3.3597e-04
# Epoch 4/5
# 1s - loss: 3.2086e-04
# Epoch 5/5
# 1s - loss: 3.1433e-04
# Train Score: 26.11 RMSE
# Test Score: 47.91 RMSE
# ***

# %%
# create a function to define the LSTM model
def make_model(dt_back=10):
    model = Sequential()
    model.add(LSTM(100, input_shape=(dt_back,1)))   # input_shape=(1, dt_back)  , activation='relu')
    model.add(Dense(1))                             # , activation='sigmoid'
    model.compile(loss='mean_squared_error', optimizer='adam')   # loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']
    
    return model
# end def make_model():

# %%
# prepare for hyperparameter search by first wrapping the model in Keras Classifier
model = KerasClassifier(build_fn=make_model,dt_back=dt_back,verbose=0)

# define the grid search parameters
batch_size_n = [2]    # [2,4,8,10,12,14,16,18,20]
epoch_n = [2]   # [2,5,7,10]
param_grid = dict(batch_size=batch_size_n, epochs=epoch_n)

# %%
# perform hyperparameter grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1)

# %%
# Cell-with-GridSearch
#grid_result = grid.fit(trainX,trainY)

#print("Best score=%f with %s" % (grid_result.best_score_, grid_result.best_params_))

print('Best model: batch size=11, ','Train Score=21.09 RMSE, ','Test Score=23.97 RMSE ')
# Out:
# Best model: batch size=11,  Train Score=21.09 RMSE,  Test Score=23.97 RMSE

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(dt_back,1)))   # input_shape=(1, dt_back)  , activation='relu')
model.add(Dense(1))                             # , activation='sigmoid'
model.compile(loss='mean_squared_error', optimizer='adam')   # loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']

model.fit(trainX, trainY, epochs=5, batch_size=11, verbose=2)

# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# invert predictions
p_train_pred_t = scaler.inverse_transform(trainPredict)
trainY1 = scaler.inverse_transform([trainY])
p_test_pred_t = scaler.inverse_transform(testPredict)
testY1 = scaler.inverse_transform([testY])

# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY1[0], p_train_pred_t[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY1[0], p_test_pred_t[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Epoch 1/5
# 6s - loss: 0.0033
# Epoch 2/5
# 3s - loss: 3.3325e-04
# Epoch 3/5
# 3s - loss: 3.1331e-04
# Epoch 4/5
# 3s - loss: 2.8316e-04
# Epoch 5/5
# 3s - loss: 2.8280e-04
# Train Score: 22.08 RMSE
# Test Score: 25.21 RMSE

# %%
# shift train predictions for plotting
p_train_pred_pl_t = np.empty_like(p_t)
p_train_pred_pl_t[:, :] = np.nan
p_train_pred_pl_t[dt_back:len(p_train_pred_t)+dt_back, :] = p_train_pred_t

# shift test predictions for plotting
p_test_pred_pl_t = np.empty_like(p_t)
p_test_pred_pl_t[:, :] = np.nan
p_test_pred_pl_t[len(p_train_pred_t)+(dt_back*2)+1:len(p_t)-1, :] = p_test_pred_t

trainY2 = np.reshape(trainY1,(trainY1.shape[1],trainY1.shape[0]))   #np.array(trainY1)   #.shape

p_pl_t=scaler.inverse_transform(p_t)

# %%
# plot baseline and predictions
fig1 = plt.figure()

plt.plot(p_pl_t)   # (trainY2)   # [2700:2900]
plt.plot(p_train_pred_pl_t)   #(p_train_pred_t)    # [2700:2900]
plt.plot(p_test_pred_pl_t)    # [2700:2900]
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333142648146">

# %%
# plot prediction errors
fig2 = plt.figure()

plt.plot(p_pl_t-p_train_pred_pl_t)   # (trainY2)   # [2700:2900]
#plt.plot(p_train_pred_pl_t)   #(p_train_pred_t)    # [2700:2900]
#plt.plot(p_test_pred_pl_t)    # [2700:2900]
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333142648146">

# %%
# plot prediction errors
fig2 = plt.figure()

#plt.plot(p_pl_t-p_train_pred_pl_t)   # (trainY2)   # [2700:2900]
plt.plot(p_pl_t-p_test_pred_pl_t)   #(p_train_pred_t)    # [2700:2900]
#plt.plot(p_test_pred_pl_t)    # [2700:2900]
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333142648146">

# %% [markdown]
# Prediction errors show that, the LSTM model partially captures volatility clustering effects!
